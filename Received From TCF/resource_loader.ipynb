# %%
import json
import requests

# %%
with open('resources.json', 'r') as f:
    resources = json.load(f)

# %%
token = "Bearer eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.._KVAaiPO1Ufcl9bOmNliF_sI8IXAEAx4cU5PhNjD5ww"
url = "http://104.248.233.145/api/resource"

# %%
# loop through the dataframe and send a POST request for each row
for idx, obj in enumerate(resources):
    response = requests.post(url, json=obj, headers={"Authorization": token})
    if response.status_code == 201:
        print(f"Resource {idx + 1} created successfully.")
    else:
        print(f"Resource {idx + 1} failed to create. Status code: {response.status_code}, Response: {response.text}")
        print(obj)
# Out:
# Resource 1 created successfully.
# Resource 2 created successfully.
# Resource 3 created successfully.
# Resource 4 created successfully.
# Resource 5 created successfully.
# Resource 6 created successfully.
# Resource 7 created successfully.
# Resource 8 created successfully.
# Resource 9 created successfully.
# Resource 10 created successfully.
